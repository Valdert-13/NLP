# %%
import os
from telegram.ext  import Updater, CommandHandler, MessageHandler, Filters
import string
from pymorphy2 import MorphAnalyzer
from stop_words import get_stop_words
import annoy
from gensim.models import Word2Vec, FastText
import pickle
import numpy as np
from tqdm.notebook import tqdm
import pandas as pd

# %%
path_file_input = "G:/data/NLP/Otvety.txt"
path_file_output = "G:/data/NLP/prepared_answers.txt"

# %%
assert True

#Small preprocess of the answers

question = None
written = False

with open(path_file_output, "w", encoding="utf8") as fout:
    with open(path_file_input, "r", encoding="utf8") as fin:
        for line in tqdm(fin):
            if line.startswith("---"):
                written = False
                continue
            if not written and question is not None:
                fout.write(question.replace("\t", " ").strip() + "\t" + line.replace("\t", " "))
                written = True
                question = None
                continue
            if not written:
                question = line.strip()
                continue
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…

# %%
def preprocess_txt(line):
    spls = "".join(i for i in line.strip() if i not in exclude).split()
    spls = [morpher.parse(i.lower())[0].normal_form for i in spls]
    spls = [i for i in spls if i not in sw and i != ""]
    return spls

# %%
assert True

# Preprocess for models fitting

sentences = []

morpher = MorphAnalyzer()
sw = set(get_stop_words("ru"))
exclude = set(string.punctuation)
c = 0

with open(path_file_input, "r", encoding="utf8") as fin:
    for line in tqdm(fin):
        spls = preprocess_txt(line)
        sentences.append(spls)
        c += 1
        if c > 500000:
            break
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…

# %%
sentences = [i for i in sentences if len(i) > 2]
modelFT = FastText(sentences=sentences, size=100, min_count=1, window=5)
modelFT.save("ft_model")

# %%
modelFT = FastText.load("ft_model")
ft_index = annoy.AnnoyIndex(100 ,'angular')

index_map = {}
counter = 0

with open(path_file_output, "r", encoding="utf8") as f:
    for line in tqdm(f):
        n_ft = 0
        spls = line.split("\t")
        index_map[counter] = spls[1]
        question = preprocess_txt(spls[0])
        vector_ft = np.zeros(100)
        for word in question:
            if word in modelFT:
                vector_ft += modelFT[word]
                n_ft += 1
        if n_ft > 0:
            vector_ft = vector_ft / n_ft
        ft_index.add_item(counter, vector_ft)
            
        counter += 1

ft_index.build(10)
ft_index.save('speaker.ann')
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…
# D:\anaconda3\envs\NLP\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   from ipykernel import kernelapp as app
# D:\anaconda3\envs\NLP\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   app.launch_new_instance()
# True

# %%
ft_index = annoy.AnnoyIndex(100, 'angular')
ft_index.load('speaker.ann')
# Out:
# True

# %%
ft_index.get_nns_by_vector(np.zeros(100), 2)
# Out:
# [20216, 26555]

# %%
shop_data = pd.read_csv("ProductsDataset.csv")


shop_data['text'] = shop_data['title'] + " " + shop_data["descrirption"]
shop_data['text'] = shop_data['text'].apply(lambda x: preprocess_txt(str(x)))
shop_data.head()
# Out:
#                   title                                       descrirption  \
# 0     Юбка детская ORBY  Новая, не носили ни разу. В реале красивей чем...
# 1             Ботильоны  Новые,привезены из Чехии ,указан размер 40,но ...
# 2                 Брюки  Размер 40-42. Брюки почти новые - не знаю как ...
# 3  Продам детские шапки  Продам шапки,кажда 200р.Розовая и белая проданны.
# 4                Блузка  Темно-синяя, 42 размер,состояние отличное,как ...
#
#                  product_id  category_id subcategory_id  \
# 0  58e3cfe6132ca50e053f5f82         22.0           2211
# 1  5667531b2b7f8d127d838c34          9.0            902
# 2  59534826aaab284cba337e06          9.0            906
# 3  57de544096ad842e26de8027         22.0           2217
# 4  5ad4d2626c86cb168d212022          9.0            907
#
#                                           properties  \
# 0        {'detskie_razmer_rost': '81-86 (1,5 года)'}
# 1  {'zhenskaya_odezhda_tzvet': 'Зеленый', 'visota...
# 2  {'zhenskaya_odezhda_dzhinsy_bryuki_tip': 'Брюк...
# 3  {'detskie_pol': 'Девочкам', 'detskaya_odezhda_...
# 4  {'zhenskaya_odezhda_tzvet': 'Синий', 'zhenskay...
#
#                                          image_links  \
# 0  http://cache3.youla.io/files/images/360_360/58...
# 1  http://cache3.youla.io/files/images/360_360/5b...
# 2  http://cache3.youla.io/files/images/360_360/59...
# 3  http://cache3.youla.io/files/images/360_360/57...
# 4  http://cache3.youla.io/files/images/360_360/5a...
#
#                                                 text
# 0  [юбка, детский, orby, новый, носить, реал, кра...
# 1  [ботильон, новыепривезти, чехия, указанный, ра...
# 2  [брюки, размер, 4042, брюки, новое, знать, мер...
# 3  [продать, детский, шапка, продать, шапкикажда,...
# 4  [блузка, темносиний, 42, размерсостояние, отли...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

vectorizer = CountVectorizer(ngram_range=(1, 2))

# %%
idxs = set(np.random.randint(0, len(index_map), len(shop_data)))
negative_texts = [" ".join(preprocess_txt(index_map[i])) for i in idxs]
positive_texts = [" ".join(val) for val in shop_data['text'].values]

# %%
dataset = negative_texts + positive_texts
labels = np.zeros(len(dataset))
labels[len(negative_texts):] = np.ones(len(positive_texts))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.2, stratify=labels,
                                                    random_state=13)

# %%
x_train_vec = vectorizer.fit_transform(X_train)
x_test_vec = vectorizer.transform(X_test)

lr = LogisticRegression().fit(x_train_vec, y_train)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_true=y_test, y_pred=lr.predict(x_test_vec))
# Out:
# 0.9798809861150467

# %%
assert True
import pickle

with open("index_speaker.pkl", "wb") as f:
    pickle.dump(index_map, f)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer().fit(X_train)

# %%
np.mean(tfidf_vect.idf_)
# Out:
# 10.921957563612375

# %%
idfs = {v[0]: v[1] for v in zip(tfidf_vect.vocabulary_, tfidf_vect.idf_)}
idfs
# Out:
# {'юбка': 9.376426898696234,
#  'белый': 6.978531625897864,
#  '46': 11.248229075597825,
#  'одеть': 11.248229075597825,
#  'размер': 11.248229075597825,
#  'примерка': 11.248229075597825,
#  'подкинуть': 11.248229075597825,
#  'me': 11.248229075597825,
#  'real': 11.248229075597825,
#  'pно': 11.248229075597825,
#  'успех': 10.842763967489661,
#  'песнь': 11.248229075597825,
#  'выпустить': 10.842763967489661,
#  'европа': 11.248229075597825,
#  'аж': 11.248229075597825,
#  'поставить': 11.248229075597825,
#  'сторона': 11.248229075597825,
#  'bluesblue': 10.842763967489661,
#  'sunday': 11.248229075597825,
#  'англия': 11.248229075597825,
#  'blueswaiting': 11.248229075597825,
#  'for': 11.248229075597825,
#  'sun': 10.842763967489661,
#  'франция': 11.248229075597825,
#  'bluesland': 11.248229075597825,
#  'ho': 11.248229075597825,
#  'pамериканский': 11.248229075597825,
#  'достигнуть': 11.248229075597825,
#  '50': 11.248229075597825,
#  'место': 11.248229075597825,
#  'чарт': 11.248229075597825,
#  'billboard': 11.248229075597825,
#  'hot': 11.248229075597825,
#  'изз': 10.842763967489661,
#  'неудачный': 11.248229075597825,
#  'выбор': 11.248229075597825,
#  'стать': 11.248229075597825,
#  'визитный': 10.842763967489661,
#  'группа': 11.248229075597825,
#  'выступление': 11.248229075597825,
#  'концертный': 11.248229075597825,
#  'версия': 10.842763967489661,
#  'поместить': 11.248229075597825,
#  'an': 11.248229075597825,
#  'american': 11.248229075597825,
#  'prayer': 11.248229075597825,
#  'молитва': 11.248229075597825,
#  '1978': 11.248229075597825,
#  'распад': 11.248229075597825,
#  'рокобозреватель': 10.842763967489661,
#  'джек': 9.23332605505556,
#  'финя': 11.248229075597825,
#  'возможный': 11.248229075597825,
#  'живых': 11.248229075597825,
#  'исполнение': 11.248229075597825,
#  'вообще': 11.248229075597825,
#  'попасть': 11.248229075597825,
#  'greatest': 11.248229075597825,
#  'hits': 11.248229075597825,
#  '1980': 11.248229075597825,
#  'in': 11.248229075597825,
#  'concert': 11.248229075597825,
#  '1991': 11.248229075597825,
#  'pпесня': 11.248229075597825,
#  'дважды': 11.248229075597825,
#  'звучать': 11.248229075597825,
#  'биографический': 11.248229075597825,
#  'фильм': 11.248229075597825,
#  'оливер': 11.248229075597825,
#  'стоун': 11.248229075597825,
#  'середина': 11.248229075597825,
#  'лента': 10.55508189503788,
#  'живая': 10.842763967489661,
#  'заключительный': 11.248229075597825,
#  'титр': 11.248229075597825,
#  'h2запись': 11.248229075597825,
#  'студииh2': 11.248229075597825,
#  'pзапись': 11.248229075597825,
#  'занять': 11.248229075597825,
#  'ноябрь': 11.248229075597825,
#  '1969': 11.248229075597825,
#  'продюсер': 11.248229075597825,
#  'половина': 11.248229075597825,
#  'ротшильд': 11.248229075597825,
#  'стараться': 11.248229075597825,
#  'добиться': 11.248229075597825,
#  'совершенство': 11.248229075597825,
#  'ремастеринг': 10.842763967489661,
#  'сессия': 11.248229075597825,
#  'включить': 11.248229075597825,
#  'обновить': 11.248229075597825,
#  '2006': 11.248229075597825,
#  'услышать': 11.248229075597825,
#  'настраивать': 10.149616786929716,
#  'гитарист': 11.248229075597825,
#  'робби': 11.248229075597825,
#  'кригер': 11.248229075597825,
#  'мы': 11.248229075597825,
#  'идти': 11.248229075597825,
#  'ванную': 11.248229075597825,
#  'странно': 11.248229075597825,
#  'комментировать': 11.248229075597825,
#  'джим': 11.248229075597825,
#  'моррисон': 11.248229075597825,
#  'слово': 11.248229075597825,
#  'звукоинженер': 11.248229075597825,
#  'брюс': 11.248229075597825,
#  'ботник': 11.248229075597825,
#  'явно': 11.248229075597825,
#  'подшофе': 10.842763967489661,
#  'входить': 11.248229075597825,
#  'образ': 11.248229075597825,
#  'блюзовый': 11.248229075597825,
#  'певца': 11.248229075597825,
#  'пропускать': 11.248229075597825,
#  'некоторый': 11.248229075597825,
#  'текст': 11.248229075597825,
#  'pосновный': 11.248229075597825,
#  'работа': 11.248229075597825,
#  'начаться': 11.248229075597825,
#  'присоединиться': 11.248229075597825,
#  'штатный': 10.842763967489661,
#  'электры': 11.248229075597825,
#  'лонний': 11.248229075597825,
#  'мак': 11.248229075597825,
#  'англрусск': 10.55508189503788,
#  'бас': 10.55508189503788,
#  'бывший': 11.248229075597825,
#  'популярный': 11.248229075597825,
#  'lovin': 11.248229075597825,
#  'spoonful': 11.248229075597825,
#  'джон': 10.842763967489661,
#  'себастиан': 11.248229075597825,
#  'псевдоним': 11.248229075597825,
#  'puglese': 11.248229075597825,
#  'гармоника': 11.248229075597825,
#  'клавишник': 11.248229075597825,
#  'рэй': 11.248229075597825,
#  'манзарек': 11.248229075597825,
#  'пересесть': 11.248229075597825,
#  'электрический': 11.248229075597825,
#  'вурлитцера': 11.248229075597825,
#  'обычный': 11.248229075597825,
#  'рояль': 11.248229075597825,
#  'интересно': 11.248229075597825,
#  'брать': 11.248229075597825,
#  'гитара': 11.248229075597825,
#  'развить': 10.842763967489661,
#  'линия': 10.55508189503788,
#  'кричать': 11.248229075597825,
#  'do': 11.248229075597825,
#  'it': 10.55508189503788,
#  'lonnie': 11.248229075597825,
#  'неверный': 11.248229075597825,
#  'цитировать': 11.248229075597825,
#  'обращение': 11.248229075597825,
#  'позаимствовать': 11.248229075597825,
#  'ход': 11.248229075597825,
#  'сей': 11.248229075597825,
#  'неизвестно': 11.248229075597825,
#  'войти': 11.248229075597825,
#  'h2участник': 11.248229075597825,
#  'записиh2': 10.55508189503788,
#  'h3музыкантыh3': 11.248229075597825,
#  'ul': 11.248229075597825,
#  'liджим': 11.248229075597825,
#  'вокалli': 11.248229075597825,
#  'liрэй': 10.55508189503788,
#  'клавишныеli': 11.248229075597825,
#  'liробби': 11.248229075597825,
#  'гитараli': 11.248229075597825,
#  'liджон': 11.248229075597825,
#  'денсмор': 11.248229075597825,
#  'ударныеli': 11.248229075597825,
#  'liлонний': 11.248229075597825,
#  'гармоникаliul': 10.55508189503788,
#  'h3записьh3': 11.248229075597825,
#  'liполый': 5.199675561505717,
#  'продюсерli': 4.797758653453649,
#  'liбрюс': 6.668376697594024,
#  'звукоинженерliul': 8.72250043128957,
#  'h2каверверсииh2': 9.45646960636977,
#  'liбританский': 10.55508189503788,
#  'status': 11.248229075597825,
#  'quo': 11.248229075597825,
#  'исполнять': 11.248229075597825,
#  'энергичный': 11.248229075597825,
#  'композиция': 11.248229075597825,
#  'турне': 11.248229075597825,
#  'германия': 11.248229075597825,
#  'быстро': 11.248229075597825,
#  'закрепиться': 11.248229075597825,
#  'сетлист': 11.248229075597825,
#  'поздний': 11.248229075597825,
#  'piledriver': 11.248229075597825,
#  '1972': 11.248229075597825,
#  'живом': 11.248229075597825,
#  'двойник': 11.248229075597825,
#  'live': 11.248229075597825,
#  '1977li': 11.248229075597825,
#  'liамериканский': 10.842763967489661,
#  'состав': 11.248229075597825,
#  'blue': 11.248229075597825,
#  'öyster': 11.248229075597825,
#  'cult': 11.248229075597825,
#  'представить': 11.248229075597825,
#  'двойной': 11.248229075597825,
#  'extraterrestrial': 11.248229075597825,
#  '1982': 11.248229075597825,
#  'причём': 10.55508189503788,
#  'сцена': 11.248229075597825,
#  'версииli': 11.248229075597825,
#  'liкригер': 10.842763967489661,
#  'постгранжгруппа': 10.842763967489661,
#  'creed': 11.248229075597825,
#  'фестиваль': 11.248229075597825,
#  'вудсток': 11.248229075597825,
#  '1999': 11.248229075597825,
#  'бонус': 11.248229075597825,
#  'мультиплатиновый': 11.248229075597825,
#  'human': 11.248229075597825,
#  'clay': 11.248229075597825,
#  '1990ха': 11.248229075597825,
#  'играть': 11.248229075597825,
#  'эрик': 11.248229075597825,
#  'бардон': 11.248229075597825,
#  'постоянно': 11.248229075597825,
#  'концерт': 10.842763967489661,
#  '1993': 11.248229075597825,
#  'liveверсия': 11.248229075597825,
#  'совместно': 11.248229075597825,
#  'brian': 11.248229075597825,
#  'auger': 11.248229075597825,
#  'band': 11.248229075597825,
#  'access': 11.248229075597825,
#  'all': 11.248229075597825,
#  'areas': 10.842763967489661,
#  'калифорнийский': 11.248229075597825,
#  'stone': 11.248229075597825,
#  'temple': 11.248229075597825,
#  'pilots': 11.248229075597825,
#  'house': 11.248229075597825,
#  'of': 8.415015731541608,
#  '2000': 11.248229075597825,
#  'годуli': 11.248229075597825,
#  'liизвестный': 11.248229075597825,
#  'кавер': 10.55508189503788,
#  'канадский': 11.248229075597825,
#  'mahogany': 11.248229075597825,
#  'rush': 11.248229075597825,
#  'whats': 10.331938343723671,
#  'next': 11.248229075597825,
#  'индстриалметалгруппа': 10.331938343723671,
#  'ministry': 11.248229075597825,
#  'last': 11.248229075597825,
#  'sucker': 10.842763967489661,
#  '2007': 11.248229075597825,
#  'британский': 11.248229075597825,
#  'frankie': 11.248229075597825,
#  'goes': 10.842763967489661,
#  'to': 10.842763967489661,
#  'hollywood': 10.842763967489661,
#  'записать': 11.248229075597825,
#  'тройной': 11.248229075597825,
#  'rage': 11.248229075597825,
#  'hard': 10.842763967489661,
#  '1986': 11.248229075597825,
#  'элка': 11.248229075597825,
#  'брукс': 11.248229075597825,
#  'певица': 11.248229075597825,
#  'английский': 11.248229075597825,
#  'ритм': 9.995466107102457,
#  'эндблюз': 11.248229075597825,
#  'команда': 11.248229075597825,
#  'vinegar': 11.248229075597825,
#  'joe': 11.248229075597825,
#  'сольный': 11.248229075597825,
#  'electric': 10.842763967489661,
#  'lady': 11.248229075597825,
#  '2005li': 9.995466107102457,
#  'liканадский': 11.248229075597825,
#  'jeff': 11.248229075597825,
#  'healey': 11.248229075597825,
#  'исполнить': 11.248229075597825,
#  'дом': 11.248229075597825,
#  'дороги': 11.248229075597825,
#  'li': 11.248229075597825,
#  'liшведский': 10.842763967489661,
#  'imperiet': 11.248229075597825,
#  '80х': 11.248229075597825,
#  'живой': 11.248229075597825,
#  '2a': 11.248229075597825,
#  'augusti': 11.248229075597825,
#  '1985li': 10.331938343723671,
#  'deep': 10.842763967489661,
#  'purple': 11.248229075597825,
#  'infinite': 11.248229075597825,
#  '2017го': 10.842763967489661,
#  'годаliul': 11.248229075597825,
#  'h2примечанияh2': 11.248229075597825,
#  'трудолюбие': 10.55508189503788,
#  'подвижность': 11.248229075597825,
#  'мариновать': 11.248229075597825,
#  'чеснок': 11.248229075597825,
#  'оригинальный': 11.248229075597825,
#  'блюдо': 11.248229075597825,
#  'подать': 11.248229075597825,
#  'праздничный': 11.248229075597825,
#  'стол': 11.248229075597825,
#  'качество': 11.248229075597825,
#  'закуска': 11.248229075597825,
#  'баловать': 11.248229075597825,
#  'близкие': 11.248229075597825,
#  'пикантный': 11.248229075597825,
#  'brмариновать': 11.248229075597825,
#  'литровый': 11.248229075597825,
#  'банка': 10.842763967489661,
#  'итак': 11.248229075597825,
#  'головка': 11.248229075597825,
#  'разделять': 11.248229075597825,
#  'зубок': 10.842763967489661,
#  'чистить': 11.248229075597825,
#  'складывать': 11.248229075597825,
#  'укладывать': 11.248229075597825,
#  'плотно': 11.248229075597825,
#  'верх': 11.248229075597825,
#  'необходимый': 11.248229075597825,
#  'налить': 11.248229075597825,
#  'кипяток': 11.248229075597825,
#  'полностью': 11.248229075597825,
#  'покрыть': 11.248229075597825,
#  'добавлять': 10.842763967489661,
#  'ст': 11.248229075597825,
#  'ложка': 11.248229075597825,
#  'уксус': 11.248229075597825,
#  'чайный': 10.55508189503788,
#  'соль': 11.248229075597825,
#  'столовый': 11.248229075597825,
#  'сахара': 11.248229075597825,
#  'brзатем': 11.248229075597825,
#  'ставить': 11.248229075597825,
#  'кастрюля': 11.248229075597825,
#  'наполнить': 11.248229075597825,
#  'горячий': 11.248229075597825,
#  'вод': 11.248229075597825,
#  'попадать': 11.248229075597825,
#  'горлышко': 11.248229075597825,
#  'прокипеть': 11.248229075597825,
#  'течение': 10.149616786929716,
#  'минута': 11.248229075597825,
#  'вынимать': 11.248229075597825,
#  'сутки': 11.248229075597825,
#  'дублёнка': 11.248229075597825,
#  'привезти': 11.248229075597825,
#  'сша': 11.248229075597825,
#  'двухсторонний': 11.248229075597825,
#  'иск': 10.842763967489661,
#  'вьетнам': 11.248229075597825,
#  'mysqli': 10.842763967489661,
#  'new': 11.248229075597825,
#  'mysqlilocalhost': 11.248229075597825,
#  'user': 9.995466107102457,
#  'password': 11.248229075597825,
#  'basebrbrif': 11.248229075597825,
#  'stmt': 11.248229075597825,
#  'mysqligtprepareselect': 10.331938343723671,
#  'namecompany': 10.842763967489661,
#  'city': 11.248229075597825,
#  'from': 10.842763967489661,
#  'company': 11.248229075597825,
#  'stmtgtexecutebrbr': 11.248229075597825,
#  'stmtgtbindresultname': 11.248229075597825,
#  'citybrbr': 11.248229075597825,
#  'while': 10.331938343723671,
#  'stmtgtfetch': 11.248229075597825,
#  'echo': 11.248229075597825,
#  'ltdivgtnamecityltdivgtbr': 11.248229075597825,
#  'brbr': 11.248229075597825,
#  'stmtgtclosebrbrmysqligtclose': 11.248229075597825,
#  '2800': 7.475468137503187,
#  'литр': 11.248229075597825,
#  '1680': 11.248229075597825,
#  'делимый': 11.248229075597825,
#  'получать': 11.248229075597825,
#  '560литр': 11.248229075597825,
#  '560': 11.248229075597825,
#  'умножать': 11.248229075597825,
#  '1120': 11.248229075597825,
#  '2800brbrp': 11.248229075597825,
#  'функция': 11.248229075597825,
#  'глючный': 11.248229075597825,
#  'монитор': 8.94564398260378,
#  'brhttpsmarketyandexruproduct13137367showuid166715057863648420616005ampnid54539ampglfilter491358612103913ampglfilter491358812103947ampglfilter49135972ampglfilter4913622144ampglfilter7893318152865ampcontextsearchbrbrить': 11.248229075597825,
#  'brbrhttpsmarketyandexruproduct1719436797showuid166715643996131737016001ampnid54539ampglfilter491358612103913ampglfilter491358812103947ampglfilter49135972ampglfilter4913622144ampglfilter7893318152865ampcontextsearch': 11.248229075597825,
#  'аккуратный': 8.99693727699133,
#  '1818227brн': 11.248229075597825,
#  'такbrbrp': 11.248229075597825,
#  'аполлон': 11.248229075597825,
#  'предводитель': 11.248229075597825,
#  'муза': 10.842763967489661,
#  'прекрасный': 11.248229075597825,
#  'музыкант': 11.248229075597825,
#  'певец': 10.55508189503788,
#  'миф': 11.248229075597825,
#  'противоречивый': 11.248229075597825,
#  'талантливый': 11.248229075597825,
#  'жестокий': 11.248229075597825,
#  'участвовать': 11.248229075597825,
#  'бунт': 11.248229075597825,
#  'зевс': 11.248229075597825,
#  'терпеть': 11.248229075597825,
#  'соперник': 11.248229075597825,
#  '36': 11.248229075597825,
#  'обутый': 10.842763967489661,
#  'раз': 11.248229075597825,
#  'район': 8.683279718136289,
#  'площадь': 11.248229075597825,
#  'куйбышев': 11.248229075597825,
#  'вопрос': 11.248229075597825,
#  'звонитеписать': 11.248229075597825,
#  'договориться': 11.248229075597825,
#  'весна': 11.248229075597825,
#  'осень': 11.248229075597825,
#  'набойка': 10.55508189503788,
#  'заменить': 11.248229075597825,
#  '38': 11.248229075597825,
#  'ил2': 8.72250043128957,
#  'штурмовик': 9.74415167882155,
#  'игра': 11.248229075597825,
#  'вести': 11.248229075597825,
#  'авиасимулятор': 11.248229075597825,
#  'майкрософт': 11.248229075597825,
#  'флайта': 8.94564398260378,
#  'симулятор': 11.248229075597825,
#  'многий': 11.248229075597825,
#  'ролик': 11.248229075597825,
#  '4243': 11.248229075597825,
#  'обмен': 11.248229075597825,
#  'продамролик': 11.248229075597825,
#  'конёк': 11.248229075597825,
#  '4243ь': 11.248229075597825,
#  'солевой': 10.842763967489661,
#  'лампа': 10.842763967489661,
#  'свадебный': 8.112734859668675,
#  'состоянииразмер': 11.248229075597825,
#  '4244цвета': 11.248229075597825,
#  'белыйв': 10.842763967489661,
#  'комплект': 9.5434809833594,
#  'перчатка': 11.248229075597825,
#  'красивый': 11.248229075597825,
#  'люлькакачели': 11.248229075597825,
#  'новорождённый': 11.248229075597825,
#  'люлькаот': 10.149616786929716,
#  'месяц': 11.248229075597825,
#  '911': 8.540178874495616,
#  'килограмм': 11.248229075597825,
#  'дорожекрасивый': 11.248229075597825,
#  'мягкий': 11.248229075597825,
#  'музыка': 11.248229075597825,
#  'вибрация': 11.248229075597825,
#  'распечатать': 10.331938343723671,
#  'простирать': 10.55508189503788,
#  'ребёнок': 11.248229075597825,
#  'рука': 11.248229075597825,
#  'батарейка': 10.842763967489661,
#  'внутри': 11.248229075597825,
#  'поставленыупаковка': 10.55508189503788,
#  'инструкция': 11.248229075597825,
#  'иметься': 11.248229075597825,
#  'дык': 10.149616786929716,
#  'ауди': 11.248229075597825,
#  'поди': 11.248229075597825,
#  'модель': 11.248229075597825,
#  'прошлое': 10.842763967489661,
#  'ась': 11.248229075597825,
#  'полёт': 11.248229075597825,
#  'фантазия': 8.203706637874403,
#  'шагать': 9.108162912101555,
#  'точно': 10.842763967489661,
#  'прогадать': 11.248229075597825,
#  'шагнуть': 11.248229075597825,
#  ...}

# %%
ft_index_shop = annoy.AnnoyIndex(100 ,'angular')

midf = np.mean(tfidf_vect.idf_)

index_map_shop = {}
counter = 0

for i in tqdm(range(len(shop_data))):
    n_ft = 0
    index_map_shop[counter] = (shop_data.loc[i, "title"], shop_data.loc[i, "image_links"])
    vector_ft = np.zeros(100)
    for word in shop_data.loc[i, "text"]:
        if word in modelFT:
            vector_ft += modelFT[word] * idfs.get(word, midf)
            n_ft += idfs.get(word, midf)
    if n_ft > 0:
        vector_ft = vector_ft / n_ft
    ft_index_shop.add_item(counter, vector_ft)
    counter += 1

ft_index_shop.build(10)
ft_index_shop.save('shop.ann')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=35548.0), HTML(value='')))
# D:\anaconda3\envs\NLP\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   del sys.path[0]
# D:\anaconda3\envs\NLP\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# True

# %%
assert True
import pickle

with open("index_shop.pkl", "wb") as f:
    pickle.dump(index_map, f)

# %%
def embed_txt(txt, idfs, midf):
    n_ft = 0
    vector_ft = np.zeros(100)
    for word in txt:
        if word in modelFT:
            vector_ft += modelFT[word] * idfs.get(word, midf)
            n_ft += idfs.get(word, midf)
    return vector_ft / n_ft

# %%
ft_index_shop.get_nns_by_vector(np.zeros(100), 1, include_distances=True)
# Out:
# ([102], [1.4142135381698608])

# %%
updater = Updater(token='1145420328:AAEQhT_v04e5cJIqQ-JOfccgVzDqtCiqLRg') # Токен API к Telegram
dispatcher = updater.dispatcher


def startCommand(bot, update):
    bot.send_message(chat_id=update.message.chat_id, text='Добрый день')

def textMessage(bot, update):
    
    input_txt = preprocess_txt(update.message.text)
    vect = vectorizer.transform([" ".join(input_txt)])
    prediction = lr.predict(vect)
    
    if prediction[0] == 1:
        vect_ft = embed_txt(input_txt, idfs, midf)
        ft_index_shop_val = ft_index_shop.get_nns_by_vector(vect_ft, 5)
        for item in ft_index_shop_val:
            title, image = index_map_shop[item]
            bot.send_message(chat_id=update.message.chat_id, text="title: {} image: {}".format(title, image))
        return
    vect_ft = embed_txt(input_txt, {}, 1)
    ft_index_val, distances = ft_index.get_nns_by_vector(vect_ft, 1, include_distances=True)
    if distances[0] > 0.2:
        print(distances[0])
        bot.send_message(chat_id=update.message.chat_id, text="Моя твоя не понимать")
        return
    bot.send_message(chat_id=update.message.chat_id, text=index_map[ft_index_val[0]])
        
start_command_handler = CommandHandler('start', startCommand)
text_message_handler = MessageHandler(Filters.text, textMessage)
dispatcher.add_handler(start_command_handler)
dispatcher.add_handler(text_message_handler)
updater.start_polling(clean=True)
updater.idle()
# Out:
# D:\anaconda3\envs\NLP\lib\site-packages\ipykernel_launcher.py:1: TelegramDeprecationWarning: Old Handler API is deprecated - see https://git.io/fxJuV for details
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# InvalidToken                              Traceback (most recent call last)
# <ipython-input-31-4e6c077f91d0> in <module>
#       1 updater = Updater(token='1145420328:AAEQhT_v04e5cJIqQ-JOfccgVzDqtCiqLRg') # Токен API к Telegram
#       2 dispatcher = updater.dispatcher
# ----> 3 updater = Updater('TOKEN', use_context=True)
#       4
#       5 def startCommand(bot, update):
#
# D:\anaconda3\envs\NLP\lib\site-packages\telegram\ext\updater.py in __init__(self, token, base_url, workers, bot, private_key, private_key_password, user_sig_handler, request_kwargs, persistence, defaults, use_context, dispatcher, base_file_url)
#     163                                private_key=private_key,
#     164                                private_key_password=private_key_password,
# --> 165                                defaults=defaults)
#     166             self.update_queue = Queue()
#     167             self.job_queue = JobQueue()
#
# D:\anaconda3\envs\NLP\lib\site-packages\telegram\bot.py in __init__(self, token, base_url, base_file_url, request, private_key, private_key_password, defaults)
#     128                  private_key_password=None,
#     129                  defaults=None):
# --> 130         self.token = self._validate_token(token)
#     131
#     132         # Gather default
#
# D:\anaconda3\envs\NLP\lib\site-packages\telegram\bot.py in _validate_token(token)
#     195         left, sep, _right = token.partition(':')
#     196         if (not sep) or (not left.isdigit()) or (len(left) < 3):
# --> 197             raise InvalidToken()
#     198
#     199         return token
#
# InvalidToken: Invalid token
